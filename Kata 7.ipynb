# %% [markdown]
# # Ejercicio 1 y 2 - Bucles While y For

# %%
new_planet = ''
planets = []

while new_planet.lower() != 'done':
    if new_planet:
        planets.append(new_planet)
    new_planet = input('Enter a new planet ')

print("La lista de planetas es:\n ")
for planet in planets:
    print(planet)
# Out:
# La lista de planetas es:
#
# Tierra-X
# Galifreid
# Amogus

# %% [markdown]
# ## Ejercicio - Escribir declaraciones if, else, y elif

# %%
ast_vel = 49    # Velocidad del asteroide
lim_vel = 25    # Velocidad límite que define si debe haber una advertencia

if ast_vel > lim_vel:
    print("UN ASTEROIDE VA CHOCAR CONTRA LA TIERRA, CORRAN POR SUS VIDAS D:")
# Out:
# UN ASTEROIDE VA CHOCAR CONTRA LA TIERRA, CORRAN POR SUS VIDAS D:

# %%
asteroide = 19
limite = 20

if asteroide < limite:
    print("Un asteroide se dirige a la tierra, no representa ningún problema")
elif asteroide >= limite:
    print("Si miran al cielo y observan un gran rayo de luz, un asteoride se dirige a la tierra, disfruten el espectáculo")
else:
    print("No pasa nada")
# Out:
# Un asteroide se dirige a la tierra, no representa ningún problema

# %% [markdown]
# # Ejercicio: Uso de operadores and y or

# %%
vel_ast = 100   # Velocidad del asteroide
tam_ast = 1000  # Tamaño del asteroide

if tam_ast > 25 and vel_ast > 25:
    print("VAMOS A MORIR TODOS!!!")
elif tam_ast < 25 and vel_ast < 25:
    print("Miren el cielo y vean como se desintegra un asteroide")
elif tam_ast > 25 and tam_ast < 1000:
    print("Impacto inmitente de un asteroide")
elif tam_ast < 25 or vel_ast < 25:
    print("No hay problema alguno")
else:
    print("Hola")
# Out:
# VAMOS A MORIR TODOS!!!
